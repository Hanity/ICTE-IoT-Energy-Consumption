# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
# %cd gdrive/
# Out:
# /content/gdrive

# %%
ls
# Out:
# MyDrive/  Shareddrives/

# %%
# %cd MyDrive/
# Out:
# /content/gdrive/MyDrive

# %% [markdown]
# Descriptive Statistics

# %%
import pandas as pd

#smart = pd.read_excel('Node-red VS MD.xlsx')
applications = pd.read_excel('Final ICTE.xlsx')

# %%
smart.describe()
# Out:
#        Timestamp Untitled Question
# count          0                 0
# unique         0                 0
# top          NaN               NaN
# freq         NaN               NaN

# %%
applications.describe()
# Out:
#              Node          DB        RPI  ...  Unnamed: 16  Unnamed: 17  Unnamed: 18
# count   21.000000   21.000000  21.000000  ...          0.0          0.0          1.0
# mean   181.190476   86.066667   2.100000  ...          NaN          NaN          0.0
# std    115.000947   42.740395   0.486826  ...          NaN          NaN          NaN
# min      0.000000    0.000000   0.000000  ...          NaN          NaN          0.0
# 25%     89.100000   60.200000   2.100000  ...          NaN          NaN          0.0
# 50%    173.000000   84.300000   2.200000  ...          NaN          NaN          0.0
# 75%    285.500000  130.200000   2.300000  ...          NaN          NaN          0.0
# max    359.000000  176.100000   2.300000  ...          NaN          NaN          0.0
#
# [8 rows x 17 columns]

# %%
import pandas as pd

print("Mean by Measurement Value")
print(applications.mean())
print("\n")

print("Median by Measurement Value")
print(applications.median())
print("\n")

print("Describe  Measurement Value and Measurement Time")
applications.describe()

print("Skewness by Measurement Value")
df2 = applications.skew()

print(df2)
print("\n")
# Out:
# Mean by Measurement Value
# Node                                                 181.190476
# DB                                                    86.066667
# RPI                                                    2.100000
#   Node Application (W)                               190.250000
# Node Total Power Consumption (W)                     190.250000
# Total Time (s)                                       117.503425
#  Node Total Energy Consumption (KJ)                   22.381305
# Node  Average Energy Consumption per second (J/s)    190.250000
#  DB Application (W)                                   90.370000
# DB Total Power Consumption (W)                        90.370000
#  DB Total Time (s)                                   110.818450
#  DB Total Energy Consumption (KJ)                     10.012666
# DB Average Energy Consumption per second (J/s)        90.370000
# Unnamed: 15                                                 NaN
# Unnamed: 16                                                 NaN
# Unnamed: 17                                                 NaN
# Unnamed: 18                                            0.000000
# dtype: float64
#
#
# Median by Measurement Value
# Node                                                 173.000000
# DB                                                    84.300000
# RPI                                                    2.200000
#   Node Application (W)                               191.100000
# Node Total Power Consumption (W)                     191.100000
# Total Time (s)                                       117.560000
#  Node Total Energy Consumption (KJ)                   22.422345
# Node  Average Energy Consumption per second (J/s)    191.100000
#  DB Application (W)                                   85.100000
# DB Total Power Consumption (W)                        85.100000
#  DB Total Time (s)                                   107.861000
#  DB Total Energy Consumption (KJ)                      9.307869
# DB Average Energy Consumption per second (J/s)        85.100000
# Unnamed: 15                                                 NaN
# Unnamed: 16                                                 NaN
# Unnamed: 17                                                 NaN
# Unnamed: 18                                            0.000000
# dtype: float64
#
#
# Describe  Measurement Value and Measurement Time
# Skewness by Measurement Value
# Node                                                 0.020978
# DB                                                   0.162481
# RPI                                                 -4.408489
#   Node Application (W)                               0.011369
# Node Total Power Consumption (W)                     0.011369
# Total Time (s)                                      -1.593387
#  Node Total Energy Consumption (KJ)                  0.010771
# Node  Average Energy Consumption per second (J/s)    0.011369
#  DB Application (W)                                  0.490862
# DB Total Power Consumption (W)                       0.490862
#  DB Total Time (s)                                   0.781489
#  DB Total Energy Consumption (KJ)                    0.552737
# DB Average Energy Consumption per second (J/s)       0.490862
# Unnamed: 15                                               NaN
# Unnamed: 16                                               NaN
# Unnamed: 17                                               NaN
# Unnamed: 18                                               NaN
# dtype: float64

# %%
import pandas as pd
from scipy import stats

Node = applications['Node']
db = applications['DB']
rp = applications['RPI']

t2, p = stats.ttest_ind(Node,db ) 

#two-tail 2-sample t-test
alpha_half = 0.025 #alpha is 0.01 or level of confidence is 99%

print("p value = {:g}".format(p))
print("t value = {:g}". format(t2))

if p < alpha_half:  # null hypothesis: x comes from a normal distribution
    print("The null hypothesis can be rejected")
else:
    print("The null hypothesis is accepted")
# Out:
# p value = nan
# t value = nan
# The null hypothesis is accepted

# %%
import matplotlib.pyplot as plt
applications.plot(kind='scatter', x='Node', y='DB')
plt.title("Node-red and Mongo DB Application Energy Consumption in Watt", fontsize=20)
plt.xlabel("Node-red", labelpad=15)
plt.ylabel("Mongo DB", labelpad=15)
plt.grid()
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
 
   
df = pd.DataFrame(applications, columns= [ 'Node', 'DB', 'RPI','Node Application (W)','Node Total Power Consumption (W)	,Total Time (s)', 'Node Total Energy Consumption (KJ),Node  Average Energy Consumption per second (J/s)','Node  Aggregated Average Energy Consumption per second (J/s)','DB Application (W)','DB Total Power Consumption (W)',' DB Total Time (s)',' DB Total Energy Consumption (KJ)','FB Average Energy Consumption per second (J/s)',' Node  Aggregated Average Energy Consumption per second (J/s)',
											])
print (df)
 
 #create a correlation matrix for all the column sets except the target variable
correlation = df.corr()
print("\n")
print("Pearson Standard Correlation Coefficient Matrix")
print(correlation)
print("\n")
 
 
#Set up matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
 
#Set up a seaborn heatmap
#seaborne aesthetics https://seaborn.pydata.org/tutorial/aesthetics.html 
sns.set_style("white")
 
# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
 
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
#      Node  ...   Node  Aggregated Average Energy Consumption per second (J/s)
# 0     0.0  ...                                                NaN
# 1    22.2  ...                                                NaN
# 2    45.7  ...                                                NaN
# 3    47.8  ...                                                NaN
# 4    78.1  ...                                                NaN
# 5    89.9  ...                                                NaN
# 6    89.1  ...                                                NaN
# 7   118.7  ...                                                NaN
# 8   130.0  ...                                                NaN
# 9   135.0  ...                                                NaN
# 10  173.0  ...                                                NaN
# 11  209.2  ...                                                NaN
# 12  224.7  ...                                                NaN
# 13  255.1  ...                                                NaN
# 14  285.5  ...                                                NaN
# 15  274.2  ...                                                NaN
# 16  302.0  ...                                                NaN
# 17  302.0  ...                                                NaN
# 18  322.6  ...                                                NaN
# 19  341.2  ...                                                NaN
# 20  359.0  ...                                                NaN
# 21    NaN  ...                                                NaN
#
# [22 rows x 13 columns]
#
#
# Pearson Standard Correlation Coefficient Matrix
#                                                         Node  ...   Node  Aggregated Average Energy Consumption per second (J/s)
# Node                                                1.000000  ...                                                NaN
# DB                                                 -0.130727  ...                                                NaN
# RPI                                                 0.443302  ...                                                NaN
# Node Application (W)                                     NaN  ...                                                NaN
# Node Total Power Consumption (W)\t,Total Time (s)        NaN  ...                                                NaN
# Node Total Energy Consumption (KJ),Node  Averag...       NaN  ...                                                NaN
# Node  Aggregated Average Energy Consumption per...       NaN  ...                                                NaN
# DB Application (W)                                       NaN  ...                                                NaN
# DB Total Power Consumption (W)                     -0.359327  ...                                                NaN
#  DB Total Time (s)                                 -0.575617  ...                                                NaN
#  DB Total Energy Consumption (KJ)                  -0.400322  ...                                                NaN
# FB Average Energy Consumption per second (J/s)           NaN  ...                                                NaN
#  Node  Aggregated Average Energy Consumption pe...       NaN  ...                                                NaN
#
# [13 rows x 13 columns]
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# Inferential Statistics

# %%
print (df)
 
 
#create a correlation matrix for all the column sets except the target variable
correlation = df.corr()
print("\n")
print("Pearson Standard Correlation Coefficient Matrix")
print(correlation)
print("\n")
 
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(correlation, dtype=bool))
 

#Set up matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
 
#Set up a seaborn heatmap
#seaborne aesthetics https://seaborn.pydata.org/tutorial/aesthetics.html 
sns.set_style("white")
 
# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
 
#Turn on annotations for correlation values
#annot = True
#annot_kws = {"size": 12}
 
# Draw the heatmap with the mask and correct aspect ratio
heatmap = sns.heatmap(correlation, mask = mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5},
            annot = True, annot_kws = {"size": 12})
 
#Add ticks for labels
sns.set_style({'xtick.bottom': True}, {'ytick.left': True})
 
#Export heatmap as an image
heatmap.get_figure().savefig('heatmap_Sensors.png', bbox_inches='tight')
# Out:
#      Node  ...   Node  Aggregated Average Energy Consumption per second (J/s)
# 0     0.0  ...                                                NaN
# 1    22.2  ...                                                NaN
# 2    45.7  ...                                                NaN
# 3    47.8  ...                                                NaN
# 4    78.1  ...                                                NaN
# 5    89.9  ...                                                NaN
# 6    89.1  ...                                                NaN
# 7   118.7  ...                                                NaN
# 8   130.0  ...                                                NaN
# 9   135.0  ...                                                NaN
# 10  173.0  ...                                                NaN
# 11  209.2  ...                                                NaN
# 12  224.7  ...                                                NaN
# 13  255.1  ...                                                NaN
# 14  285.5  ...                                                NaN
# 15  274.2  ...                                                NaN
# 16  302.0  ...                                                NaN
# 17  302.0  ...                                                NaN
# 18  322.6  ...                                                NaN
# 19  341.2  ...                                                NaN
# 20  359.0  ...                                                NaN
# 21    NaN  ...                                                NaN
#
# [22 rows x 13 columns]
#
#
# Pearson Standard Correlation Coefficient Matrix
#                                                         Node  ...   Node  Aggregated Average Energy Consumption per second (J/s)
# Node                                                1.000000  ...                                                NaN
# DB                                                 -0.130727  ...                                                NaN
# RPI                                                 0.443302  ...                                                NaN
# Node Application (W)                                     NaN  ...                                                NaN
# Node Total Power Consumption (W)\t,Total Time (s)        NaN  ...                                                NaN
# Node Total Energy Consumption (KJ),Node  Averag...       NaN  ...                                                NaN
# Node  Aggregated Average Energy Consumption per...       NaN  ...                                                NaN
# DB Application (W)                                       NaN  ...                                                NaN
# DB Total Power Consumption (W)                     -0.359327  ...                                                NaN
#  DB Total Time (s)                                 -0.575617  ...                                                NaN
#  DB Total Energy Consumption (KJ)                  -0.400322  ...                                                NaN
# FB Average Energy Consumption per second (J/s)           NaN  ...                                                NaN
#  Node  Aggregated Average Energy Consumption pe...       NaN  ...                                                NaN
#
# [13 rows x 13 columns]
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#Correlation Hypothesis Testing by using pvalues
import pandas as pd
from scipy import stats
df = pd.DataFrame(applications, columns = ['Node','DB'])

#Calculate Pearson Correlation r and p value
pearsonCoeff_rvalue, p_value = stats.pearsonr(df["Node"], df["DB"])  #define the columns to perform calculations on
print("Pearson Correlation Coefficient r value : ", pearsonCoeff_rvalue.round(decimals=3), "and a P-value of:", p_value.round(decimals =3)) # Results 
print("\n")
 
#Conduct Correlation Coefficient Hypothesis Testing
#Use 2 tail test
#Confidence level is 95%, alpha is 0.05 and alpha/2 is 0.025
alpha = 0.05
alpha_half = 0.025
 
if p_value < alpha_half:  # null hypothesis: x comes from a normal distribution
    print("Conclusion drawn: The null hypothesis can be rejected")
else:
    print("Conclusion drawn: The null hypothesis is accepted")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-17d2fa66c5e6> in <module>()
#       5
#       6 #Calculate Pearson Correlation r and p value
# ----> 7 pearsonCoeff_rvalue, p_value = stats.pearsonr(df["Node"], df["DB"])  #define the columns to perform calculations on
#       8 print("Pearson Correlation Coefficient r value : ", pearsonCoeff_rvalue.round(decimals=3), "and a P-value of:", p_value.round(decimals =3)) # Results
#       9 print("\n")
#
# /usr/local/lib/python3.7/dist-packages/scipy/stats/stats.py in pearsonr(x, y)
#    3528     # scipy.linalg.norm(xm) does not overflow if xm is, for example,
#    3529     # [-5e210, 5e210, 3e200, -3e200]
# -> 3530     normxm = linalg.norm(xm)
#    3531     normym = linalg.norm(ym)
#    3532
#
# /usr/local/lib/python3.7/dist-packages/scipy/linalg/misc.py in norm(a, ord, axis, keepdims, check_finite)
#     140     # Differs from numpy only in non-finite handling and the use of blas.
#     141     if check_finite:
# --> 142         a = np.asarray_chkfinite(a)
#     143     else:
#     144         a = np.asarray(a)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#     484     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#     485         raise ValueError(
# --> 486             "array must not contain infs or NaNs")
#     487     return a
#     488
#
# ValueError: array must not contain infs or NaNs

# %%
applications.boxplot(column=['Node', 'DB', 'RPI'], grid=False)
plt.title("IOT Features in watts")
plt.xlabel("Applications and Device")
plt.ylabel("Measurement Values")
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Text(0, 0.5, 'Measurement Values')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
 
   
df = pd.DataFrame(applications, columns= [ 'Node', 'DB', 'RPI'])
print (df)
 
 #create a correlation matrix for all the column sets except the target variable
correlation = df.corr()
print("\n")
print("Pearson Standard Correlation Coefficient Matrix")
print(correlation)
print("\n")
 
 
#Set up matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
 
#Set up a seaborn heatmap
#seaborne aesthetics https://seaborn.pydata.org/tutorial/aesthetics.html 
sns.set_style("white")
 
# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
 
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
#      Node     DB  RPI
# 0     0.0    0.0  0.0
# 1    22.2  176.1  2.1
# 2    45.7   45.7  2.1
# 3    47.8   47.8  2.2
# 4    78.1   60.2  2.1
# 5    89.9   89.9  2.2
# 6    89.1   89.1  2.2
# 7   118.7  139.5  2.2
# 8   130.0  132.2  2.2
# 9   135.0  134.8  2.2
# 10  173.0  132.3  2.2
# 11  209.2  130.2  2.1
# 12  224.7   79.7  2.3
# 13  255.1   80.1  2.3
# 14  285.5   84.3  2.3
# 15  274.2   85.9  2.1
# 16  302.0   64.3  2.2
# 17  302.0   77.7  2.2
# 18  322.6   32.8  2.3
# 19  341.2   37.8  2.3
# 20  359.0   87.0  2.3
# 21    NaN    NaN  NaN
#
#
# Pearson Standard Correlation Coefficient Matrix
#           Node        DB       RPI
# Node  1.000000 -0.130727  0.443302
# DB   -0.130727  1.000000  0.411157
# RPI   0.443302  0.411157  1.000000

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
 
   
df = pd.DataFrame(applications, columns= [ 'Node', 'DB', 'RPI','Node Application (W)','Node Total Power Consumption (W)','Total Time (s)', 'Node Total Energy Consumption (KJ)',
                                          'Node  Average Energy Consumption per second (J/s)',
                                          'DB Application (W)','DB Total Power Consumption (W)',' DB Total Time (s)',' DB Total Energy Consumption (KJ)','DB Average Energy Consumption per second (J/s)'
											])
print (df)
 
 #create a correlation matrix for all the column sets except the target variable
correlation = df.corr()
print("\n")
print("Pearson Standard Correlation Coefficient Matrix")
print(correlation)
print("\n")
 
 
#Set up matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
 
#Set up a seaborn heatmap
#seaborne aesthetics https://seaborn.pydata.org/tutorial/aesthetics.html 
sns.set_style("white")
 
# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
 
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
#      Node  ...  DB Average Energy Consumption per second (J/s)
# 0     0.0  ...                                             NaN
# 1    22.2  ...                                           176.1
# 2    45.7  ...                                            45.7
# 3    47.8  ...                                            47.8
# 4    78.1  ...                                            60.2
# 5    89.9  ...                                            89.9
# 6    89.1  ...                                            89.1
# 7   118.7  ...                                           139.5
# 8   130.0  ...                                           132.2
# 9   135.0  ...                                           134.8
# 10  173.0  ...                                           132.3
# 11  209.2  ...                                           130.2
# 12  224.7  ...                                            79.7
# 13  255.1  ...                                            80.1
# 14  285.5  ...                                            84.3
# 15  274.2  ...                                            85.9
# 16  302.0  ...                                            64.3
# 17  302.0  ...                                            77.7
# 18  322.6  ...                                            32.8
# 19  341.2  ...                                            37.8
# 20  359.0  ...                                            87.0
# 21    NaN  ...                                             NaN
#
# [22 rows x 13 columns]
#
#
# Pearson Standard Correlation Coefficient Matrix
#                                                        Node  ...  DB Average Energy Consumption per second (J/s)
# Node                                               1.000000  ...                                       -0.359327
# DB                                                -0.130727  ...                                        1.000000
# RPI                                                0.443302  ...                                       -0.332835
# Node Application (W)                                    NaN  ...                                             NaN
# Node Total Power Consumption (W)                   1.000000  ...                                       -0.359327
# Total Time (s)                                     0.491552  ...                                       -0.384078
# Node Total Energy Consumption (KJ)                      NaN  ...                                             NaN
# Node  Average Energy Consumption per second (J/s)  1.000000  ...                                       -0.359327
# DB Application (W)                                      NaN  ...                                             NaN
# DB Total Power Consumption (W)                    -0.359327  ...                                        1.000000
#  DB Total Time (s)                                -0.575617  ...                                       -0.012005
#  DB Total Energy Consumption (KJ)                 -0.400322  ...                                        0.995706
# DB Average Energy Consumption per second (J/s)    -0.359327  ...                                        1.000000
#
# [13 rows x 13 columns]
